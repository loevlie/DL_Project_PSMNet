# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random
import matplotlib.pyplot as plt
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable
from tqdm import tqdm
from IPython.display import display
# %matplotlib inline

# %% [markdown]
# ## Download KITTI
# #### http://www.cvlibs.net/datasets/kitti/eval_scene_flow.php?benchmark=stereo

# %% [markdown]
# ## Create data loaders

# %%
class KITTI(Dataset):
    def __init__(self, path, transform=None, train = True):
        self.transform = transform
        self.img0_dir = path + "train_set/left/"
        self.img1_dir = path + "train_set/right/"
        self.gt_dir = path + "train_set/disp/"
        self.train = train
        if train:
          self.size = int(len(os.listdir(self.gt_dir))*0.8)
        else:
          self.size = int(len(os.listdir(self.gt_dir))*0.2)
          self.remainder = int(len(os.listdir(self.gt_dir))*0.8)
          
        self.h = 256
        self.w = 416

    def __len__(self):
        return self.size
    def __getitem__(self, idx):
        if self.train:
          img0_path = self.img0_dir + str(idx).zfill(6) + "_10.png"
          img1_path = self.img1_dir + str(idx).zfill(6) + "_10.png"
          gt_path = self.gt_dir + str(idx).zfill(6) + "_10.png"
          img0 = Image.open(img0_path).convert('RGB')
          img1 = Image.open(img1_path).convert('RGB')
          gt = np.ascontiguousarray(Image.open(gt_path), dtype=np.float32)
          w,h  = img0.size
          self.r_h = random.randint(0,h-self.h)
          self.r_w = random.randint(0,w-self.w)
          img0 = img0.crop((self.r_w,self.r_h, self.r_w + self.w,self.r_h + self.h))
          img1 = img1.crop((self.r_w,self.r_h, self.r_w + self.w,self.r_h + self.h))
          gt =  gt[self.r_h:self.r_h+self.h, self.r_w:self.r_w + self.w ]
          if self.transform:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
          return img0, img1, gt
        else:
          idx += self.remainder
          img0_path = self.img0_dir + str(idx).zfill(6) + "_10.png"
          img1_path = self.img1_dir + str(idx).zfill(6) + "_10.png"
          gt_path = self.gt_dir + str(idx).zfill(6) + "_10.png"
          img0 = Image.open(img0_path).convert('RGB')
          img1 = Image.open(img1_path).convert('RGB')
          w,h  = img0.size
          img0 = img0.crop((w-416, h-320, w, h))
          img1 = img1.crop((w-416, h-320, w, h))
          gt = Image.open(gt_path)
          gt = gt.crop((w-416, h-320, w, h))
          gt = np.ascontiguousarray(gt,dtype=np.float32)
          if self.transform:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
          return img0, img1, gt

# %%
# !unzip CMU_CLEAN
# Out:
# Archive:  CMU_CLEAN.zip
#    creating: CMU_CLEAN/
#    creating: CMU_CLEAN/train_set/
#    creating: CMU_CLEAN/train_set/left/
#   inflating: CMU_CLEAN/train_set/left/000235_10.png
#   inflating: CMU_CLEAN/train_set/left/000180_10.png
#   inflating: CMU_CLEAN/train_set/left/000127_10.png
#   inflating: CMU_CLEAN/train_set/left/000118_10.png
#   inflating: CMU_CLEAN/train_set/left/000058_10.png
#   inflating: CMU_CLEAN/train_set/left/000086_10.png
#   inflating: CMU_CLEAN/train_set/left/000121_10.png
#   inflating: CMU_CLEAN/train_set/left/000181_10.png
#   inflating: CMU_CLEAN/train_set/left/000216_10.png
#   inflating: CMU_CLEAN/train_set/left/000210_10.png
#   inflating: CMU_CLEAN/train_set/left/000124_10.png
#   inflating: CMU_CLEAN/train_set/left/000097_10.png
#   inflating: CMU_CLEAN/train_set/left/000093_10.png
#   inflating: CMU_CLEAN/train_set/left/000188_10.png
#   inflating: CMU_CLEAN/train_set/left/000045_10.png
#   inflating: CMU_CLEAN/train_set/left/000241_10.png
#   inflating: CMU_CLEAN/train_set/left/000089_10.png
#   inflating: CMU_CLEAN/train_set/left/000145_10.png
#   inflating: CMU_CLEAN/train_set/left/000041_10.png
#   inflating: CMU_CLEAN/train_set/left/000218_10.png
#   inflating: CMU_CLEAN/train_set/left/000223_10.png
#   inflating: CMU_CLEAN/train_set/left/000059_10.png
#   inflating: CMU_CLEAN/train_set/left/000107_10.png
#   inflating: CMU_CLEAN/train_set/left/000002_10.png
#   inflating: CMU_CLEAN/train_set/left/000064_10.png
#   inflating: CMU_CLEAN/train_set/left/000242_10.png
#   inflating: CMU_CLEAN/train_set/left/000214_10.png
#   inflating: CMU_CLEAN/train_set/left/000112_10.png
#   inflating: CMU_CLEAN/train_set/left/000134_10.png
#   inflating: CMU_CLEAN/train_set/left/000172_10.png
#   inflating: CMU_CLEAN/train_set/left/000200_10.png
#   inflating: CMU_CLEAN/train_set/left/000219_10.png
#   inflating: CMU_CLEAN/train_set/left/000163_10.png
#   inflating: CMU_CLEAN/train_set/left/000032_10.png
#   inflating: CMU_CLEAN/train_set/left/000062_10.png
#   inflating: CMU_CLEAN/train_set/left/000009_10.png
#   inflating: CMU_CLEAN/train_set/left/000175_10.png
#   inflating: CMU_CLEAN/train_set/left/000019_10.png
#   inflating: CMU_CLEAN/train_set/left/000028_10.png
#   inflating: CMU_CLEAN/train_set/left/000137_10.png
#   inflating: CMU_CLEAN/train_set/left/000160_10.png
#   inflating: CMU_CLEAN/train_set/left/000132_10.png
#   inflating: CMU_CLEAN/train_set/left/000025_10.png
#   inflating: CMU_CLEAN/train_set/left/000147_10.png
#   inflating: CMU_CLEAN/train_set/left/000128_10.png
#   inflating: CMU_CLEAN/train_set/left/000067_10.png
#   inflating: CMU_CLEAN/train_set/left/000051_10.png
#   inflating: CMU_CLEAN/train_set/left/000152_10.png
#   inflating: CMU_CLEAN/train_set/left/000046_10.png
#   inflating: CMU_CLEAN/train_set/left/000204_10.png
#   inflating: CMU_CLEAN/train_set/left/000033_10.png
#   inflating: CMU_CLEAN/train_set/left/000006_10.png
#   inflating: CMU_CLEAN/train_set/left/000020_10.png
#   inflating: CMU_CLEAN/train_set/left/000034_10.png
#   inflating: CMU_CLEAN/train_set/left/000168_10.png
#   inflating: CMU_CLEAN/train_set/left/000136_10.png
#   inflating: CMU_CLEAN/train_set/left/000022_10.png
#   inflating: CMU_CLEAN/train_set/left/000238_10.png
#   inflating: CMU_CLEAN/train_set/left/000053_10.png
#   inflating: CMU_CLEAN/train_set/left/000014_10.png
#   inflating: CMU_CLEAN/train_set/left/000195_10.png
#   inflating: CMU_CLEAN/train_set/left/000060_10.png
#   inflating: CMU_CLEAN/train_set/left/000106_10.png
#   inflating: CMU_CLEAN/train_set/left/000150_10.png
#   inflating: CMU_CLEAN/train_set/left/000198_10.png
#   inflating: CMU_CLEAN/train_set/left/000004_10.png
#   inflating: CMU_CLEAN/train_set/left/000227_10.png
#   inflating: CMU_CLEAN/train_set/left/000209_10.png
#   inflating: CMU_CLEAN/train_set/left/000207_10.png
#   inflating: CMU_CLEAN/train_set/left/000126_10.png
#   inflating: CMU_CLEAN/train_set/left/000146_10.png
#   inflating: CMU_CLEAN/train_set/left/000074_10.png
#   inflating: CMU_CLEAN/train_set/left/000133_10.png
#   inflating: CMU_CLEAN/train_set/left/000203_10.png
#   inflating: CMU_CLEAN/train_set/left/000048_10.png
#   inflating: CMU_CLEAN/train_set/left/000083_10.png
#   inflating: CMU_CLEAN/train_set/left/000007_10.png
#   inflating: CMU_CLEAN/train_set/left/000138_10.png
#   inflating: CMU_CLEAN/train_set/left/000222_10.png
#   inflating: CMU_CLEAN/train_set/left/000036_10.png
#   inflating: CMU_CLEAN/train_set/left/000135_10.png
#   inflating: CMU_CLEAN/train_set/left/000110_10.png
#   inflating: CMU_CLEAN/train_set/left/000162_10.png
#   inflating: CMU_CLEAN/train_set/left/000114_10.png
#   inflating: CMU_CLEAN/train_set/left/000047_10.png
#   inflating: CMU_CLEAN/train_set/left/000191_10.png
#   inflating: CMU_CLEAN/train_set/left/000035_10.png
#   inflating: CMU_CLEAN/train_set/left/000084_10.png
#   inflating: CMU_CLEAN/train_set/left/000170_10.png
#   inflating: CMU_CLEAN/train_set/left/000194_10.png
#   inflating: CMU_CLEAN/train_set/left/000111_10.png
#   inflating: CMU_CLEAN/train_set/left/000161_10.png
#   inflating: CMU_CLEAN/train_set/left/000076_10.png
#   inflating: CMU_CLEAN/train_set/left/000065_10.png
#   inflating: CMU_CLEAN/train_set/left/000082_10.png
#   inflating: CMU_CLEAN/train_set/left/000013_10.png
#   inflating: CMU_CLEAN/train_set/left/000068_10.png
#   inflating: CMU_CLEAN/train_set/left/000190_10.png
#   inflating: CMU_CLEAN/train_set/left/000018_10.png
#   inflating: CMU_CLEAN/train_set/left/000087_10.png
#   inflating: CMU_CLEAN/train_set/left/000199_10.png
#   inflating: CMU_CLEAN/train_set/left/000066_10.png
#   inflating: CMU_CLEAN/train_set/left/000057_10.png
#   inflating: CMU_CLEAN/train_set/left/000072_10.png
#   inflating: CMU_CLEAN/train_set/left/000184_10.png
#   inflating: CMU_CLEAN/train_set/left/000185_10.png
#   inflating: CMU_CLEAN/train_set/left/000049_10.png
#   inflating: CMU_CLEAN/train_set/left/000078_10.png
#   inflating: CMU_CLEAN/train_set/left/000075_10.png
#   inflating: CMU_CLEAN/train_set/left/000225_10.png
#   inflating: CMU_CLEAN/train_set/left/000177_10.png
#   inflating: CMU_CLEAN/train_set/left/000027_10.png
#   inflating: CMU_CLEAN/train_set/left/000164_10.png
#   inflating: CMU_CLEAN/train_set/left/000143_10.png
#   inflating: CMU_CLEAN/train_set/left/000171_10.png
#   inflating: CMU_CLEAN/train_set/left/000220_10.png
#   inflating: CMU_CLEAN/train_set/left/000070_10.png
#   inflating: CMU_CLEAN/train_set/left/000154_10.png
#   inflating: CMU_CLEAN/train_set/left/000016_10.png
#   inflating: CMU_CLEAN/train_set/left/000155_10.png
#   inflating: CMU_CLEAN/train_set/left/000071_10.png
#   inflating: CMU_CLEAN/train_set/left/000015_10.png
#   inflating: CMU_CLEAN/train_set/left/000005_10.png
#   inflating: CMU_CLEAN/train_set/left/000102_10.png
#   inflating: CMU_CLEAN/train_set/left/000063_10.png
#   inflating: CMU_CLEAN/train_set/left/000212_10.png
#   inflating: CMU_CLEAN/train_set/left/000017_10.png
#   inflating: CMU_CLEAN/train_set/left/000024_10.png
#   inflating: CMU_CLEAN/train_set/left/000043_10.png
#   inflating: CMU_CLEAN/train_set/left/000001_10.png
#   inflating: CMU_CLEAN/train_set/left/000213_10.png
#   inflating: CMU_CLEAN/train_set/left/000234_10.png
#   inflating: CMU_CLEAN/train_set/left/000096_10.png
#   inflating: CMU_CLEAN/train_set/left/000108_10.png
#   inflating: CMU_CLEAN/train_set/left/000215_10.png
#   inflating: CMU_CLEAN/train_set/left/000224_10.png
#   inflating: CMU_CLEAN/train_set/left/000179_10.png
#   inflating: CMU_CLEAN/train_set/left/000193_10.png
#   inflating: CMU_CLEAN/train_set/left/000125_10.png
#   inflating: CMU_CLEAN/train_set/left/000205_10.png
#   inflating: CMU_CLEAN/train_set/left/000192_10.png
#   inflating: CMU_CLEAN/train_set/left/000026_10.png
#   inflating: CMU_CLEAN/train_set/left/000243_10.png
#   inflating: CMU_CLEAN/train_set/left/000054_10.png
#   inflating: CMU_CLEAN/train_set/left/000156_10.png
#   inflating: CMU_CLEAN/train_set/left/000140_10.png
#   inflating: CMU_CLEAN/train_set/left/000085_10.png
#   inflating: CMU_CLEAN/train_set/left/000021_10.png
#   inflating: CMU_CLEAN/train_set/left/000165_10.png
#   inflating: CMU_CLEAN/train_set/left/000206_10.png
#   inflating: CMU_CLEAN/train_set/left/000239_10.png
#   inflating: CMU_CLEAN/train_set/left/000061_10.png
#   inflating: CMU_CLEAN/train_set/left/000010_10.png
#   inflating: CMU_CLEAN/train_set/left/000088_10.png
#   inflating: CMU_CLEAN/train_set/left/000176_10.png
#   inflating: CMU_CLEAN/train_set/left/000095_10.png
#   inflating: CMU_CLEAN/train_set/left/000081_10.png
#   inflating: CMU_CLEAN/train_set/left/000103_10.png
#   inflating: CMU_CLEAN/train_set/left/000119_10.png
#   inflating: CMU_CLEAN/train_set/left/000037_10.png
#   inflating: CMU_CLEAN/train_set/left/000183_10.png
#   inflating: CMU_CLEAN/train_set/left/000039_10.png
#   inflating: CMU_CLEAN/train_set/left/000230_10.png
#   inflating: CMU_CLEAN/train_set/left/000178_10.png
#   inflating: CMU_CLEAN/train_set/left/000073_10.png
#   inflating: CMU_CLEAN/train_set/left/000144_10.png
#   inflating: CMU_CLEAN/train_set/left/000139_10.png
#   inflating: CMU_CLEAN/train_set/left/000157_10.png
#   inflating: CMU_CLEAN/train_set/left/000148_10.png
#   inflating: CMU_CLEAN/train_set/left/000077_10.png
#   inflating: CMU_CLEAN/train_set/left/000229_10.png
#   inflating: CMU_CLEAN/train_set/left/000232_10.png
#   inflating: CMU_CLEAN/train_set/left/000109_10.png
#   inflating: CMU_CLEAN/train_set/left/000186_10.png
#   inflating: CMU_CLEAN/train_set/left/000202_10.png
#   inflating: CMU_CLEAN/train_set/left/000042_10.png
#   inflating: CMU_CLEAN/train_set/left/000011_10.png
#   inflating: CMU_CLEAN/train_set/left/000003_10.png
#   inflating: CMU_CLEAN/train_set/left/000130_10.png
#   inflating: CMU_CLEAN/train_set/left/000090_10.png
#   inflating: CMU_CLEAN/train_set/left/000182_10.png
#   inflating: CMU_CLEAN/train_set/left/000038_10.png
#   inflating: CMU_CLEAN/train_set/left/000141_10.png
#   inflating: CMU_CLEAN/train_set/left/000208_10.png
#   inflating: CMU_CLEAN/train_set/left/000079_10.png
#   inflating: CMU_CLEAN/train_set/left/000233_10.png
#   inflating: CMU_CLEAN/train_set/left/000153_10.png
#   inflating: CMU_CLEAN/train_set/left/000120_10.png
#   inflating: CMU_CLEAN/train_set/left/000008_10.png
#   inflating: CMU_CLEAN/train_set/left/000080_10.png
#   inflating: CMU_CLEAN/train_set/left/000142_10.png
#   inflating: CMU_CLEAN/train_set/left/000040_10.png
#   inflating: CMU_CLEAN/train_set/left/000050_10.png
#   inflating: CMU_CLEAN/train_set/left/000167_10.png
#   inflating: CMU_CLEAN/train_set/left/000012_10.png
#   inflating: CMU_CLEAN/train_set/left/000131_10.png
#   inflating: CMU_CLEAN/train_set/left/000187_10.png
#   inflating: CMU_CLEAN/train_set/left/000173_10.png
#   inflating: CMU_CLEAN/train_set/left/000104_10.png
#   inflating: CMU_CLEAN/train_set/left/000197_10.png
#   inflating: CMU_CLEAN/train_set/left/000221_10.png
#   inflating: CMU_CLEAN/train_set/left/000217_10.png
#   inflating: CMU_CLEAN/train_set/left/000052_10.png
#   inflating: CMU_CLEAN/train_set/left/000151_10.png
#   inflating: CMU_CLEAN/train_set/left/000105_10.png
#   inflating: CMU_CLEAN/train_set/left/000158_10.png
#   inflating: CMU_CLEAN/train_set/left/000030_10.png
#   inflating: CMU_CLEAN/train_set/left/000159_10.png
#   inflating: CMU_CLEAN/train_set/left/000189_10.png
#   inflating: CMU_CLEAN/train_set/left/000056_10.png
#   inflating: CMU_CLEAN/train_set/left/000100_10.png
#   inflating: CMU_CLEAN/train_set/left/000123_10.png
#   inflating: CMU_CLEAN/train_set/left/000129_10.png
#   inflating: CMU_CLEAN/train_set/left/000240_10.png
#   inflating: CMU_CLEAN/train_set/left/000174_10.png
#   inflating: CMU_CLEAN/train_set/left/000117_10.png
#   inflating: CMU_CLEAN/train_set/left/000055_10.png
#   inflating: CMU_CLEAN/train_set/left/000116_10.png
#   inflating: CMU_CLEAN/train_set/left/000069_10.png
#   inflating: CMU_CLEAN/train_set/left/000149_10.png
#   inflating: CMU_CLEAN/train_set/left/000166_10.png
#   inflating: CMU_CLEAN/train_set/left/000228_10.png
#   inflating: CMU_CLEAN/train_set/left/000044_10.png
#   inflating: CMU_CLEAN/train_set/left/000094_10.png
#   inflating: CMU_CLEAN/train_set/left/000113_10.png
#   inflating: CMU_CLEAN/train_set/left/000237_10.png
#   inflating: CMU_CLEAN/train_set/left/000031_10.png
#   inflating: CMU_CLEAN/train_set/left/000115_10.png
#   inflating: CMU_CLEAN/train_set/left/000091_10.png
#   inflating: CMU_CLEAN/train_set/left/000092_10.png
#   inflating: CMU_CLEAN/train_set/left/000236_10.png
#   inflating: CMU_CLEAN/train_set/left/000231_10.png
#   inflating: CMU_CLEAN/train_set/left/000101_10.png
#   inflating: CMU_CLEAN/train_set/left/000122_10.png
#   inflating: CMU_CLEAN/train_set/left/000169_10.png
#   inflating: CMU_CLEAN/train_set/left/000098_10.png
#   inflating: CMU_CLEAN/train_set/left/000201_10.png
#   inflating: CMU_CLEAN/train_set/left/000196_10.png
#   inflating: CMU_CLEAN/train_set/left/000023_10.png
#   inflating: CMU_CLEAN/train_set/left/000000_10.png
#   inflating: CMU_CLEAN/train_set/left/000211_10.png
#   inflating: CMU_CLEAN/train_set/left/000226_10.png
#   inflating: CMU_CLEAN/train_set/left/000029_10.png
#   inflating: CMU_CLEAN/train_set/left/000099_10.png
#    creating: CMU_CLEAN/train_set/right/
#   inflating: CMU_CLEAN/train_set/right/000235_10.png
#   inflating: CMU_CLEAN/train_set/right/000180_10.png
#   inflating: CMU_CLEAN/train_set/right/000127_10.png
#   inflating: CMU_CLEAN/train_set/right/000118_10.png
#   inflating: CMU_CLEAN/train_set/right/000058_10.png
#   inflating: CMU_CLEAN/train_set/right/000086_10.png
#   inflating: CMU_CLEAN/train_set/right/000121_10.png
#   inflating: CMU_CLEAN/train_set/right/000181_10.png
#   inflating: CMU_CLEAN/train_set/right/000216_10.png
#   inflating: CMU_CLEAN/train_set/right/000210_10.png
#   inflating: CMU_CLEAN/train_set/right/000124_10.png
#   inflating: CMU_CLEAN/train_set/right/000097_10.png
#   inflating: CMU_CLEAN/train_set/right/000093_10.png
#   inflating: CMU_CLEAN/train_set/right/000188_10.png
#   inflating: CMU_CLEAN/train_set/right/000045_10.png
#   inflating: CMU_CLEAN/train_set/right/000241_10.png
#   inflating: CMU_CLEAN/train_set/right/000089_10.png
#   inflating: CMU_CLEAN/train_set/right/000145_10.png
#   inflating: CMU_CLEAN/train_set/right/000041_10.png
#   inflating: CMU_CLEAN/train_set/right/000218_10.png
#   inflating: CMU_CLEAN/train_set/right/000223_10.png
#   inflating: CMU_CLEAN/train_set/right/000059_10.png
#   inflating: CMU_CLEAN/train_set/right/000107_10.png
#   inflating: CMU_CLEAN/train_set/right/000002_10.png
#   inflating: CMU_CLEAN/train_set/right/000064_10.png
#   inflating: CMU_CLEAN/train_set/right/000242_10.png
#   inflating: CMU_CLEAN/test_set/disp/000096_10.png
#   inflating: CMU_CLEAN/test_set/disp/000097_10.png
#   inflating: CMU_CLEAN/test_set/disp/000098_10.png
#   inflating: CMU_CLEAN/test_set/disp/000099_10.png
#    creating: CMU_CLEAN/test_set/left/
#   inflating: CMU_CLEAN/test_set/left/000000_10.png
#   inflating: CMU_CLEAN/test_set/left/000001_10.png
#   inflating: CMU_CLEAN/test_set/left/000002_10.png
#   inflating: CMU_CLEAN/test_set/left/000003_10.png
#   inflating: CMU_CLEAN/test_set/left/000004_10.png
#   inflating: CMU_CLEAN/test_set/left/000005_10.png
#   inflating: CMU_CLEAN/test_set/left/000006_10.png
#   inflating: CMU_CLEAN/test_set/left/000007_10.png
#   inflating: CMU_CLEAN/test_set/left/000008_10.png
#   inflating: CMU_CLEAN/test_set/left/000009_10.png
#   inflating: CMU_CLEAN/test_set/left/000010_10.png
#   inflating: CMU_CLEAN/test_set/left/000011_10.png
#   inflating: CMU_CLEAN/test_set/left/000012_10.png
#   inflating: CMU_CLEAN/test_set/left/000013_10.png
#   inflating: CMU_CLEAN/test_set/left/000014_10.png
#   inflating: CMU_CLEAN/test_set/left/000015_10.png
#   inflating: CMU_CLEAN/test_set/left/000016_10.png
#   inflating: CMU_CLEAN/test_set/left/000017_10.png
#   inflating: CMU_CLEAN/test_set/left/000018_10.png
#   inflating: CMU_CLEAN/test_set/left/000019_10.png
#   inflating: CMU_CLEAN/test_set/left/000020_10.png
#   inflating: CMU_CLEAN/test_set/left/000021_10.png
#   inflating: CMU_CLEAN/test_set/left/000022_10.png
#   inflating: CMU_CLEAN/test_set/left/000023_10.png
#   inflating: CMU_CLEAN/test_set/left/000024_10.png
#   inflating: CMU_CLEAN/test_set/left/000025_10.png
#   inflating: CMU_CLEAN/test_set/left/000026_10.png
#   inflating: CMU_CLEAN/test_set/left/000027_10.png
#   inflating: CMU_CLEAN/test_set/left/000028_10.png
#   inflating: CMU_CLEAN/test_set/left/000029_10.png
#   inflating: CMU_CLEAN/test_set/left/000030_10.png
#   inflating: CMU_CLEAN/test_set/left/000031_10.png
#   inflating: CMU_CLEAN/test_set/left/000032_10.png
#   inflating: CMU_CLEAN/test_set/left/000033_10.png
#   inflating: CMU_CLEAN/test_set/left/000034_10.png
#   inflating: CMU_CLEAN/test_set/left/000035_10.png
#   inflating: CMU_CLEAN/test_set/left/000036_10.png
#   inflating: CMU_CLEAN/test_set/left/000037_10.png
#   inflating: CMU_CLEAN/test_set/left/000038_10.png
#   inflating: CMU_CLEAN/test_set/left/000039_10.png
#   inflating: CMU_CLEAN/test_set/left/000040_10.png
#   inflating: CMU_CLEAN/test_set/left/000041_10.png
#   inflating: CMU_CLEAN/test_set/left/000042_10.png
#   inflating: CMU_CLEAN/test_set/left/000043_10.png
#   inflating: CMU_CLEAN/test_set/left/000044_10.png
#   inflating: CMU_CLEAN/test_set/left/000045_10.png
#   inflating: CMU_CLEAN/test_set/left/000046_10.png
#   inflating: CMU_CLEAN/test_set/left/000047_10.png
#   inflating: CMU_CLEAN/test_set/left/000048_10.png
#   inflating: CMU_CLEAN/test_set/left/000049_10.png
#   inflating: CMU_CLEAN/test_set/left/000050_10.png
#   inflating: CMU_CLEAN/test_set/left/000051_10.png
#   inflating: CMU_CLEAN/test_set/left/000052_10.png
#   inflating: CMU_CLEAN/test_set/left/000053_10.png
#   inflating: CMU_CLEAN/test_set/left/000054_10.png
#   inflating: CMU_CLEAN/test_set/left/000055_10.png
#   inflating: CMU_CLEAN/test_set/left/000056_10.png
#   inflating: CMU_CLEAN/test_set/left/000057_10.png
#   inflating: CMU_CLEAN/test_set/left/000058_10.png
#   inflating: CMU_CLEAN/test_set/left/000059_10.png
#   inflating: CMU_CLEAN/test_set/left/000060_10.png
#   inflating: CMU_CLEAN/test_set/left/000061_10.png
#   inflating: CMU_CLEAN/test_set/left/000062_10.png
#   inflating: CMU_CLEAN/test_set/left/000063_10.png
#   inflating: CMU_CLEAN/test_set/left/000064_10.png
#   inflating: CMU_CLEAN/test_set/left/000065_10.png
#   inflating: CMU_CLEAN/test_set/left/000066_10.png
#   inflating: CMU_CLEAN/test_set/left/000067_10.png
#   inflating: CMU_CLEAN/test_set/left/000068_10.png
#   inflating: CMU_CLEAN/test_set/left/000069_10.png
#   inflating: CMU_CLEAN/test_set/left/000070_10.png
#   inflating: CMU_CLEAN/test_set/left/000071_10.png
#   inflating: CMU_CLEAN/test_set/left/000072_10.png
#   inflating: CMU_CLEAN/test_set/left/000073_10.png
#   inflating: CMU_CLEAN/test_set/left/000074_10.png
#   inflating: CMU_CLEAN/test_set/left/000075_10.png
#   inflating: CMU_CLEAN/test_set/left/000076_10.png
#   inflating: CMU_CLEAN/test_set/left/000077_10.png
#   inflating: CMU_CLEAN/test_set/left/000078_10.png
#   inflating: CMU_CLEAN/test_set/left/000079_10.png
#   inflating: CMU_CLEAN/test_set/left/000080_10.png
#   inflating: CMU_CLEAN/test_set/left/000081_10.png
#   inflating: CMU_CLEAN/test_set/left/000082_10.png
#   inflating: CMU_CLEAN/test_set/left/000083_10.png
#   inflating: CMU_CLEAN/test_set/left/000084_10.png
#   inflating: CMU_CLEAN/test_set/left/000085_10.png
#   inflating: CMU_CLEAN/test_set/left/000086_10.png
#   inflating: CMU_CLEAN/test_set/left/000087_10.png
#   inflating: CMU_CLEAN/test_set/left/000088_10.png
#   inflating: CMU_CLEAN/test_set/left/000089_10.png
#   inflating: CMU_CLEAN/test_set/left/000090_10.png
#   inflating: CMU_CLEAN/test_set/left/000091_10.png
#   inflating: CMU_CLEAN/test_set/left/000092_10.png
#   inflating: CMU_CLEAN/test_set/left/000093_10.png
#   inflating: CMU_CLEAN/test_set/left/000094_10.png
#   inflating: CMU_CLEAN/test_set/left/000095_10.png
#   inflating: CMU_CLEAN/test_set/left/000096_10.png
#   inflating: CMU_CLEAN/test_set/left/000097_10.png
#   inflating: CMU_CLEAN/test_set/left/000098_10.png
#   inflating: CMU_CLEAN/test_set/right/000050_10.png
#   inflating: CMU_CLEAN/test_set/right/000051_10.png
#   inflating: CMU_CLEAN/test_set/right/000052_10.png
#   inflating: CMU_CLEAN/test_set/right/000053_10.png
#   inflating: CMU_CLEAN/test_set/right/000054_10.png
#   inflating: CMU_CLEAN/test_set/right/000055_10.png
#   inflating: CMU_CLEAN/test_set/right/000056_10.png
#   inflating: CMU_CLEAN/test_set/right/000057_10.png
#   inflating: CMU_CLEAN/test_set/right/000058_10.png
#   inflating: CMU_CLEAN/test_set/right/000059_10.png
#   inflating: CMU_CLEAN/test_set/right/000060_10.png
#   inflating: CMU_CLEAN/test_set/right/000061_10.png
#   inflating: CMU_CLEAN/test_set/right/000062_10.png
#   inflating: CMU_CLEAN/test_set/right/000063_10.png
#   inflating: CMU_CLEAN/test_set/right/000064_10.png
#   inflating: CMU_CLEAN/test_set/right/000065_10.png
#   inflating: CMU_CLEAN/test_set/right/000066_10.png
#   inflating: CMU_CLEAN/test_set/right/000067_10.png
#   inflating: CMU_CLEAN/test_set/right/000068_10.png
#   inflating: CMU_CLEAN/test_set/right/000069_10.png
#   inflating: CMU_CLEAN/test_set/right/000070_10.png
#   inflating: CMU_CLEAN/test_set/right/000071_10.png
#   inflating: CMU_CLEAN/test_set/right/000072_10.png
#   inflating: CMU_CLEAN/test_set/right/000073_10.png
#   inflating: CMU_CLEAN/test_set/right/000074_10.png
#   inflating: CMU_CLEAN/test_set/right/000075_10.png
#   inflating: CMU_CLEAN/test_set/right/000076_10.png
#   inflating: CMU_CLEAN/test_set/right/000077_10.png
#   inflating: CMU_CLEAN/test_set/right/000078_10.png
#   inflating: CMU_CLEAN/test_set/right/000079_10.png
#   inflating: CMU_CLEAN/test_set/right/000080_10.png
#   inflating: CMU_CLEAN/test_set/right/000081_10.png
#   inflating: CMU_CLEAN/test_set/right/000082_10.png
#   inflating: CMU_CLEAN/test_set/right/000083_10.png
#   inflating: CMU_CLEAN/test_set/right/000084_10.png
#   inflating: CMU_CLEAN/test_set/right/000085_10.png
#   inflating: CMU_CLEAN/test_set/right/000086_10.png
#   inflating: CMU_CLEAN/test_set/right/000087_10.png
#   inflating: CMU_CLEAN/test_set/right/000088_10.png
#   inflating: CMU_CLEAN/test_set/right/000089_10.png
#   inflating: CMU_CLEAN/test_set/right/000090_10.png
#   inflating: CMU_CLEAN/test_set/right/000091_10.png
#   inflating: CMU_CLEAN/test_set/right/000092_10.png
#   inflating: CMU_CLEAN/test_set/right/000093_10.png
#   inflating: CMU_CLEAN/test_set/right/000094_10.png
#   inflating: CMU_CLEAN/test_set/right/000095_10.png
#   inflating: CMU_CLEAN/test_set/right/000096_10.png
#   inflating: CMU_CLEAN/test_set/right/000097_10.png
#   inflating: CMU_CLEAN/test_set/right/000098_10.png
#   inflating: CMU_CLEAN/test_set/right/000099_10.png

# %%
normalize = {'mean': [0.485, 0.456, 0.406],
                   'std': [0.229, 0.224, 0.225]}
input_transforms = torchvision.transforms.Compose([transforms.ToTensor()])
test_dataset = KITTI('./CMU_CLEAN/', transform=input_transforms, train = False)
test_Loader = DataLoader(test_dataset, batch_size= 1, shuffle= False, num_workers= 4, drop_last=False)
print('Test Dataset Size:', len(test_dataset))
# Out:
# Test Dataset Size: 48

# %%
train_dataset = KITTI('./CMU_CLEAN/', transform=input_transforms,train=True)
train_loader = DataLoader(train_dataset, batch_size=4, pin_memory=True, shuffle=True, num_workers=4)

print('Train Dataset Size:', len(train_dataset))
# Out:
# Train Dataset Size: 195

# %% [markdown]
# ## Create Basic Model

# %% [markdown]
# Here we define some functions and classes from submodule.py

# %%
def conv_bn(dim, in_planes, out_planes, kernel_size, stride, pad, dilation=None):
  if dim == 2:
    return nn.Sequential(
        nn.Conv2d(in_channels=in_planes, out_channels=out_planes, kernel_size=kernel_size, stride=stride, padding=dilation if dilation > 1 else pad, dilation=dilation, bias=False),
        nn.BatchNorm2d(out_planes)
    )
  elif dim == 3:
    return nn.Sequential(
        nn.Conv3d(in_channels=in_planes, out_channels=out_planes, kernel_size=kernel_size, padding=pad, stride=stride, bias=False),
        nn.BatchNorm3d(out_planes)
    )  

class DisparityRegression(nn.Module):
  def __init__(self, max_disp):
    super(DisparityRegression, self).__init__()
    self.disp = Variable(torch.Tensor(np.reshape(np.array(range(max_disp)), [1, max_disp, 1, 1])).cuda(), requires_grad=False)

  def forward(self, x):
    disp = self.disp.repeat(x.size()[0], 1, x.size()[2], x.size()[3])
    out = torch.sum(x*disp, 1)

    return out

class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride):
        super(ConvBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, in_channels, 1)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv2 = nn.Conv2d(in_channels, out_channels, kernel_size, stride)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.conv3 = nn.Conv2d(out_channels, out_channels, 1)
        self.bn3 = nn.BatchNorm2d(out_channels)

        self.conv_sc = nn.Conv2d(in_channels, out_channels, kernel_size, stride)
        self.bn_sc = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        y = F.relu(self.bn1(self.conv1(x)))
        y = F.relu(self.bn2(self.conv2(y)))
        y = self.bn3(self.conv3(y))

        x = self.conv_sc(x)
        x = self.bn_sc(x)

        y += x
        y = F.relu(y)

        return y


class IdentityBlock(nn.Module):
    def __init__(self, in_channels):
        super(IdentityBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, in_channels, 1)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.conv2 = nn.Conv2d(in_channels, in_channels, 1)
        self.bn2 = nn.BatchNorm2d(in_channels)

    def forward(self, x):
        y = F.relu(self.bn1(self.conv1(x)))
        y = self.bn2(self.conv2(y))
        y += x
        y = F.relu(y)

        return y


class Feature(nn.Module):
    def __init__(self):
        super(Feature, self).__init__()


        self.conv1 = nn.Sequential(ConvBlock(3,32,3,1),
                                  IdentityBlock(32),
                                  IdentityBlock(32),
                                  IdentityBlock(32),
                                  IdentityBlock(32),
                                  ConvBlock(32,64,3,1),
                                  IdentityBlock(64),
                                  IdentityBlock(64),
                                  IdentityBlock(64),
                                  IdentityBlock(64),
                                  )
        
        self.conv2 = nn.Sequential(ConvBlock(3,32,3,1),
                          IdentityBlock(32),
                          IdentityBlock(32),
                          IdentityBlock(32),
                          IdentityBlock(32),
                          ConvBlock(32,64,3,1),
                          IdentityBlock(64),
                          IdentityBlock(64),
                          IdentityBlock(64),
                          IdentityBlock(64),
                          )
        
        self.conv3 = nn.Sequential(ConvBlock(3,32,3,1),
                          IdentityBlock(32),
                          IdentityBlock(32),
                          IdentityBlock(32),
                          IdentityBlock(32),
                          ConvBlock(32,64,3,1),
                          IdentityBlock(64),
                          IdentityBlock(64),
                          IdentityBlock(64),
                          IdentityBlock(64),
                          )
        
        self.conv4 = nn.Sequential(ConvBlock(3,32,3,1),
                          IdentityBlock(32),
                          IdentityBlock(32),
                          IdentityBlock(32),
                          IdentityBlock(32),
                          ConvBlock(32,64,3,1),
                          IdentityBlock(64),
                          IdentityBlock(64),
                          IdentityBlock(64),
                          IdentityBlock(64),
                          )

        self.final_conv = nn.Sequential(ConvBlock(64*4, 128, 3, 1),
                                        IdentityBlock(128),
                                        IdentityBlock(128),
                                        IdentityBlock(128),
                                        IdentityBlock(128),
                                        ConvBlock(128, 64, 3, 1),
                                        IdentityBlock(64),
                                        IdentityBlock(64),
                                        IdentityBlock(64),
                                        IdentityBlock(64),
                                        nn.Conv2d(64,32,1)
                                        )

    def forward(self, x):
        x1 = self.conv1(F.avg_pool2d(x, 4))
        x2 = self.conv2(F.avg_pool2d(x, 8))
        x3 = self.conv3(F.avg_pool2d(x, 16))
        x4 = self.conv4(F.avg_pool2d(x, 32))

        x2 = F.interpolate(x2, (x1.shape[2], x1.shape[3]), mode = 'bilinear')
        x3 = F.interpolate(x3, (x1.shape[2], x1.shape[3]), mode = 'bilinear')
        x4 = F.interpolate(x4, (x1.shape[2], x1.shape[3]), mode = 'bilinear')

        y = torch.cat((x1,x2,x3,x4), dim=1)
        y = F.dropout2d(y)
        y = self.final_conv(y)

        return y

# %%
class PSMNet(nn.Module):
  def __init__(self, max_disp):
    super(PSMNet, self).__init__()
    self.maxdisp = max_disp
    self.feature_extraction = Feature()

    self.res0 = nn.Sequential(
      conv_bn(3, 64, 32, 3, 1, 1),
      nn.ReLU(inplace=True),
      conv_bn(3, 32, 32, 3, 1, 1),
      nn.ReLU(inplace=True)
    )
    self.res1 = nn.Sequential(
      conv_bn(3, 32, 32, 3, 1, 1),
      nn.ReLU(inplace=True),
      conv_bn(3, 32, 32, 3, 1, 1),
    )
    self.res2 = nn.Sequential(
      conv_bn(3, 32, 32, 3, 1, 1),
      nn.ReLU(inplace=True),
      conv_bn(3, 32, 32, 3, 1, 1)
    )
    self.res3 = nn.Sequential(
      conv_bn(3, 32, 32, 3, 1, 1),
      nn.ReLU(inplace=True), 
      conv_bn(3, 32, 32, 3, 1, 1)
    )
    self.res4 = nn.Sequential(
      conv_bn(3, 32, 32, 3, 1, 1),
      nn.ReLU(inplace=True),
      conv_bn(3, 32, 32, 3, 1, 1)
    )
    self.classify = nn.Sequential(
      conv_bn(3, 32, 32, 3, 1, 1),
      nn.ReLU(inplace=True),
      nn.Conv3d(32, 1, kernel_size=3, padding=1, stride=1, bias=False)
    )

    for m in self.modules():
      if isinstance(m, nn.Conv2d):
        n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
        m.weight.data.normal_(0, np.sqrt(2. / n))
      elif isinstance(m, nn.Conv3d):
        n = m.kernel_size[0] * m.kernel_size[1]*m.kernel_size[2] * m.out_channels
        m.weight.data.normal_(0, np.sqrt(2. / n))
      elif isinstance(m, nn.BatchNorm2d) or isinstance(m, nn.BatchNorm3d):
        m.weight.data.fill_(1)
        m.bias.data.zero_()
      elif isinstance(m, nn.Linear):
        m.bias.data.zero_()

  def forward(self, left, right):
    ref_img_fea = self.feature_extraction(left)
    target_img_fea  = self.feature_extraction(right)

    cost = Variable(torch.FloatTensor(ref_img_fea.size()[0], ref_img_fea.size()[1]*2, self.maxdisp//4,  ref_img_fea.size()[2],  ref_img_fea.size()[3]).zero_(), volatile= not self.training).cuda()

    for i in range(self.maxdisp//4):
      if i > 0:
        cost[:, :ref_img_fea.size()[1], i, :,i:] = ref_img_fea[:,:,:,i:]
        cost[:, ref_img_fea.size()[1]:, i, :,i:] = target_img_fea[:,:,:,:-i]
      else:
        cost[:, :ref_img_fea.size()[1], i, :,:] = ref_img_fea
        cost[:, ref_img_fea.size()[1]:, i, :,:] = target_img_fea
    cost = cost.contiguous()

    cost0 = self.res0(cost)
    cost0 = self.res1(cost0) + cost0
    cost0 = self.res2(cost0) + cost0 
    cost0 = self.res3(cost0) + cost0 
    cost0 = self.res4(cost0) + cost0

    cost = self.classify(cost0)
    cost = F.interpolate(cost, [self.maxdisp,left.size()[2], left.size()[3]], mode='trilinear', align_corners=False)
    cost = torch.squeeze(cost, 1)
    pred = F.softmax(cost)
    pred = DisparityRegression(self.maxdisp)(pred)

    return pred

# %% [markdown]
# Here we implement the basic.py

# %% [markdown]
# ## Train Model

# %%
# Define network and training parameters
torch.cuda.empty_cache()
model = PSMNet(192)
device = torch.device("cuda")
model.to(device)
print(model)

num_epochs = 100
optimizer = optim.Adam(model.parameters(), lr=1e-4, betas=(0.9, 0.999))
# Out:
# PSMNet(
#   (feature_extraction): Feature(
#     (conv1): Sequential(
#       (0): ConvBlock(
#         (conv1): Conv2d(3, 3, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_sc): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#         (bn_sc): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): IdentityBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): IdentityBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): IdentityBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): IdentityBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): ConvBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_sc): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#         (bn_sc): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (6): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (7): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (8): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (9): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (conv2): Sequential(
#       (0): ConvBlock(
#         (conv1): Conv2d(3, 3, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_sc): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#         (bn_sc): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): IdentityBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): IdentityBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): IdentityBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): IdentityBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): ConvBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_sc): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#         (bn_sc): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (6): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (7): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (8): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (9): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (conv3): Sequential(
#       (0): ConvBlock(
#         (conv1): Conv2d(3, 3, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_sc): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#         (bn_sc): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): IdentityBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): IdentityBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): IdentityBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): IdentityBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): ConvBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_sc): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#         (bn_sc): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (6): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (7): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (8): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (9): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (conv4): Sequential(
#       (0): ConvBlock(
#         (conv1): Conv2d(3, 3, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_sc): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#         (bn_sc): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): IdentityBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): IdentityBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): IdentityBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): IdentityBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): ConvBlock(
#         (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_sc): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#         (bn_sc): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (6): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (7): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (8): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (9): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (final_conv): Sequential(
#       (0): ConvBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_sc): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#         (bn_sc): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): IdentityBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): IdentityBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): IdentityBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): IdentityBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): ConvBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_sc): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1))
#         (bn_sc): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (6): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (7): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (8): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (9): IdentityBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (10): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (res0): Sequential(
#     (0): Sequential(
#       (0): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): ReLU(inplace=True)
#   )
#   (res1): Sequential(
#     (0): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (res2): Sequential(
#     (0): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (res3): Sequential(
#     (0): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (res4): Sequential(
#     (0): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (classify): Sequential(
#     (0): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ReLU(inplace=True)
#     (2): Conv3d(32, 1, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   )
# )

# %%
model = PSMNet(192)
model.load_state_dict(torch.load('Model_V2_Epoch_70.pt'))
model = model.cuda()

# %%
def Test_Acc(model2,test_loader):
  def test(imgL,imgR,disp_true):

        model2.eval()
        imgL   = Variable(torch.FloatTensor(imgL))
        imgR   = Variable(torch.FloatTensor(imgR))   
        imgL, imgR = imgL.cuda(), imgR.cuda()

        with torch.no_grad():
            output3 = model2(imgL,imgR)

        pred_disp = output3.data.cpu()
        true_disp = disp_true.clone()
        
        array = np.zeros(true_disp.shape)
        array[true_disp>0] = 1

        greater_than_one = len(array[array==1])

        disp_true = np.abs(true_disp-pred_disp.numpy())
        disp_true = disp_true*array
        error = len(disp_true[disp_true>3])

        return float(error)/float(greater_than_one)

  Error = []
  for i, (imgL, imgR, disp_L) in enumerate(test_Loader):
        Error.append(1-test(imgL,imgR,disp_L))

  print(f'Final Accuracy: {np.mean(np.array(Error))}')
  return np.mean(np.array(Error))

# %%
pytorch_total_params = sum(p.numel() for p in model.parameters())
pytorch_total_trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(pytorch_total_params,pytorch_total_trainable_params)
# Out:
# 1702344 1702344

# %%
# Train loop
import time
import numpy as np
import pandas as pd
# from google.colab import files
#optimizer = optim.Adam(model.parameters(), lr=1e-3, betas=(0.9, 0.999))
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.05, patience=5, threshold=0.0001, threshold_mode='rel', cooldown=0, min_lr=0, eps=1e-08, verbose=True)
model.train()
avg_loss = []
start_time = time.time()
Acc = []
for epoch in range(num_epochs):
    total_train_loss = 0
    for i, (imgL, imgR, disp_L) in enumerate(train_loader):
      imgL = Variable(torch.FloatTensor(imgL)).to(device)
      imgR = Variable(torch.FloatTensor(imgR)).to(device)   
      disp_L = Variable(torch.FloatTensor(disp_L)).to(device)

      mask = (disp_L > 0)
      mask.detach_()

      optimizer.zero_grad()
      out = model(imgL, imgR)
      out = torch.squeeze(out, 1)
      loss = F.smooth_l1_loss(out[mask], disp_L[mask], size_average=True)

      loss.backward()
      optimizer.step()
      avg_loss.append(loss.item())
      if i%5==0:
        print('Epoch: {0}, Iter: {1}, Training Loss: {2}'.format(epoch, i, loss))

      total_train_loss += loss.item()

      torch.cuda.empty_cache()
      del imgL
      del imgR
      del disp_L
      del out
      del loss


    scheduler.step(np.mean(avg_loss))
    print(f'Scheduler saw loss: {np.mean(avg_loss)}')
    print(f'Time: {(time.time()-start_time)/60} \n') 
    model.eval()
    Acc.append(Test_Acc(model,test_Loader))
    
    model.train()
    if epoch % 10 == 0:
      print(f'Saving the model at Epoch: {epoch}, Average Loss: {np.mean(avg_loss)} as Model_V2_Epoch_{epoch}')
      torch.save(model.state_dict(), f'Model_V2_Epoch_{epoch}.pt')
      #files.download(f'Model_V2_Epoch_{epoch}.pt')
      index = [f'Epoch {i}' for i in range(len(Acc))]
      Accuracy_Values = {f'Test Accuracy':Acc}
#       df_accuracy = pd.DataFrame(Accuracy_Values,index=index)
#       df_accuracy.to_csv(f'Accuracy_Values_Epoch_{epoch}.csv')
#       files.download(f'Accuracy_Values_Epoch_{epoch}.csv')

    avg_loss = []

# %%
torch.save(model.state_dict(), f'model_V4_Modified_Epoch_{epoch}.pt')
torch.save(optimizer.state_dict(), 'optimizer.pt')
torch.save(scheduler.state_dict(), 'scheduler.pt')

# %%
model2 = PSMNet(192)
model2.load_state_dict(torch.load('model_V1_Epoch_86.pt'));
model2.eval()
device = torch.device("cuda")
model2.to(device)
# Out:
# PSMNet(
#   (feature_extraction): FeatureExtraction(
#     (firstconv): Sequential(
#       (0): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): ReLU(inplace=True)
#       (2): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): ReLU(inplace=True)
#       (4): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): ReLU(inplace=True)
#     )
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (downsample): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (3): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (4): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (6): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (7): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (8): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (9): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (10): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (11): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (12): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (13): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (14): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (15): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (branch1): Sequential(
#       (0): AvgPool2d(kernel_size=(64, 64), stride=(64, 64), padding=0)
#       (1): Sequential(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): ReLU(inplace=True)
#     )
#     (branch2): Sequential(
#       (0): AvgPool2d(kernel_size=(32, 32), stride=(32, 32), padding=0)
#       (1): Sequential(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): ReLU(inplace=True)
#     )
#     (branch3): Sequential(
#       (0): AvgPool2d(kernel_size=(16, 16), stride=(16, 16), padding=0)
#       (1): Sequential(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): ReLU(inplace=True)
#     )
#     (branch4): Sequential(
#       (0): AvgPool2d(kernel_size=(8, 8), stride=(8, 8), padding=0)
#       (1): Sequential(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): ReLU(inplace=True)
#     )
#     (lastconv): Sequential(
#       (0): Sequential(
#         (0): Conv2d(320, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): ReLU(inplace=True)
#       (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#   )
#   (dres0): Sequential(
#     (0): Sequential(
#       (0): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): ReLU(inplace=True)
#   )
#   (dres1): Sequential(
#     (0): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (dres2): Sequential(
#     (0): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (dres3): Sequential(
#     (0): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (dres4): Sequential(
#     (0): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ReLU(inplace=True)
#     (2): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (classify): Sequential(
#     (0): Sequential(
#       (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ReLU(inplace=True)
#     (2): Conv3d(32, 1, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   )
# )

# %%
# !nvidia-smi
# Out:
# Mon Nov  9 14:48:24 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.32.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P0    40W / 250W |  10681MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
class KITTI_submission(Dataset):
    def __init__(self, path, transform=None):
        self.transform = transform
        self.img0_dir = path + "training/left/"
        self.img1_dir = path + "training/right/"
        self.gt_dir = path + "training/disp/"
        self.size = int(len(os.listdir(self.gt_dir))*0.2)
        self.remainder = int(len(os.listdir(self.gt_dir))*0.8)
    def __len__(self):
        return self.size
    def __getitem__(self, idx):
          idx += self.remainder
          img0_path = self.img0_dir + str(idx).zfill(6) + "_10.png"
          img1_path = self.img1_dir + str(idx).zfill(6) + "_10.png"
          gt_path = self.gt_dir + str(idx).zfill(6) + "_10.png"
          img0 = Image.open(img0_path).convert('RGB')
          img1 = Image.open(img1_path).convert('RGB')           
          w,h  = img0.size
          img0 = img0.crop((w-416, h-320, w, h))
          img1 = img1.crop((w-416, h-320, w, h))
          gt = Image.open(gt_path)
          gt = gt.crop((w-416, h-320, w, h))  
          gt = np.ascontiguousarray(gt,dtype=np.float32)
          if self.transform:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
          return img0, img1, gt

# %%
normalize = {'mean': [0.485, 0.456, 0.406],
                   'std': [0.229, 0.224, 0.225]}
input_transforms = torchvision.transforms.Compose([transforms.ToTensor(),
                                             transforms.Normalize(**normalize)])
submission_dataset = KITTI('./CMU_CLEAN/', transform=input_transforms)
submission_loader = DataLoader(submission_dataset, batch_size= 1, shuffle= False, num_workers= 4, drop_last=False)
print('Test Dataset Size:', len(test_dataset))
# Out:
# Test Dataset Size: 48

# %%
def predict(i, imgL,imgR, DispL):

    model.eval()
    imgL   = Variable(torch.FloatTensor(imgL))
    imgR   = Variable(torch.FloatTensor(imgR))   
    imgL, imgR = imgL.cuda(), imgR.cuda()

    with torch.no_grad():
        output3 = model(imgL,imgR)

    pred_disp = np.squeeze(output3.data.cpu().numpy())
    true_disp = np.squeeze(DispL.data.cpu().numpy())
    
    pred_disp = Image.fromarray((pred_disp*256).astype('uint16'))
    pred_disp.save("pred/"+str(i)+".png")
    
    true_disp = Image.fromarray((true_disp*256).astype('uint16'))
    true_disp.save("GT/" + str(i)+".png")

# %%
for i, (imgL, imgR, DispL) in enumerate(submission_loader):
    print("Inferring",i)
    predict(i, imgL, imgR, DispL)
# Out:
# Inferring 0
# /home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/ipykernel/__main__.py:59: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/ipykernel/__main__.py:79: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Inferring 1
# Inferring 2
# Inferring 3
# Inferring 4
# Inferring 5
# Inferring 6
# Inferring 7
# Inferring 8
# Inferring 9
# Inferring 10
# Inferring 11
# Inferring 12
# Inferring 13
# Inferring 14
# Inferring 15
# Inferring 16
# Inferring 17
# Inferring 18
# Inferring 19
# Inferring 20
# Inferring 21
# Inferring 22
# Inferring 23
# Inferring 24
# Inferring 25
# Inferring 26
# Inferring 27
# Inferring 28
# Inferring 29
# Inferring 30
# Inferring 31
# Inferring 32
# Inferring 33
# Inferring 34
# Inferring 35
# Inferring 36
# Inferring 37
# Inferring 38
# Inferring 39
# Inferring 40
# Inferring 41
# Inferring 42
# Inferring 43
# Inferring 44
# Inferring 45
# Inferring 46
# Inferring 47
# Inferring 48
# Inferring 49
# Inferring 50
# Inferring 51
# Inferring 52
# Inferring 53
# Inferring 54
# Inferring 55
# Inferring 56
# Inferring 57
# Inferring 58
# Inferring 59
# Inferring 60
# Inferring 61
# Inferring 62
# Inferring 63
# Inferring 64
# Inferring 65
# Inferring 66
# Inferring 67
# Inferring 68
# Inferring 69
# Inferring 70
# Inferring 71
# Inferring 72
# Inferring 73
# Inferring 74
# Inferring 75
# Inferring 76
# Inferring 77
# Inferring 78
# Inferring 79
# Inferring 80
# Inferring 81
# Inferring 82
# Inferring 83
# Inferring 84
# Inferring 85
# Inferring 86
# Inferring 87
# Inferring 88
# Inferring 89
# Inferring 90
# Inferring 91
# Inferring 92
# Inferring 93
# Inferring 94
# Inferring 95
# Inferring 96
# Inferring 97
# Inferring 98
# Inferring 99
# Inferring 100
# Inferring 101
# Inferring 102
# Inferring 103
# Inferring 104
# Inferring 105
# Inferring 106
# Inferring 107
# Inferring 108
# Inferring 109
# Inferring 110
# Inferring 111
# Inferring 112
# Inferring 113
# Inferring 114
# Inferring 115
# Inferring 116
# Inferring 117
# Inferring 118
# Inferring 119
# Inferring 120
# Inferring 121
# Inferring 122
# Inferring 123
# Inferring 124
# Inferring 125
# Inferring 126
# Inferring 127
# Inferring 128
# Inferring 129
# Inferring 130
# Inferring 131
# Inferring 132
# Inferring 133
# Inferring 134
# Inferring 135
# Inferring 136
# Inferring 137
# Inferring 138
# Inferring 139
# Inferring 140
# Inferring 141
# Inferring 142
# Inferring 143
# Inferring 144
# Inferring 145
# Inferring 146
# Inferring 147
# Inferring 148
# Inferring 149
# Inferring 150
# Inferring 151
# Inferring 152
# Inferring 153
# Inferring 154
# Inferring 155
# Inferring 156
# Inferring 157
# Inferring 158
# Inferring 159
# Inferring 160
# Inferring 161
# Inferring 162
# Inferring 163
# Inferring 164
# Inferring 165
# Inferring 166
# Inferring 167
# Inferring 168
# Inferring 169
# Inferring 170
# Inferring 171
# Inferring 172
# Inferring 173
# Inferring 174
# Inferring 175
# Inferring 176
# Inferring 177
# Inferring 178
# Inferring 179
# Inferring 180
# Inferring 181
# Inferring 182
# Inferring 183
# Inferring 184
# Inferring 185
# Inferring 186
# Inferring 187
# Inferring 188
# Inferring 189
# Inferring 190
# Inferring 191
# Inferring 192
# Inferring 193
# Inferring 194
